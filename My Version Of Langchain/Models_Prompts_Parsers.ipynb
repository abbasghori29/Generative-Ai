# %% [markdown]
# ![image.png](attachment:b355bf6e-0fc6-4d39-97a3-a016d891b0fa.png)

# %% [markdown]
# # LangChain: Models, Prompts and Output Parsers
#
#
# ## Outline
#
#  * Direct API calls to Googel Gemini Model
#  * API calls through LangChain:
#    * Prompts
#    * Models
#    * Output parsers
